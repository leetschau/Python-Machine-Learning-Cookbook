# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from convert_to_timeseries import convert_data_to_timeseries

# %%
input_file = "data_timeseries.txt"
column_number = 2
data_timeseries = convert_data_to_timeseries(input_file, column_number)
print(type(data_timeseries))
# Out:
# <class 'pandas.core.series.Series'>

# %%
start = '2008'
end = '2015'
plt.figure()
data_timeseries[start:end].plot()
plt.title('Data from %s to %s' % (start, end))
# Out:
# Text(0.5,1,'Data from 2008 to 2015')

# %%
start = '2007-2'
end = '2007-11'
plt.figure()
data_timeseries[start:end].plot()
plt.title('Data from %s to %s' % (start,end))
# Out:
# Text(0.5,1,'Data from 2007-2 to 2007-11')

# %%
plt.show()
